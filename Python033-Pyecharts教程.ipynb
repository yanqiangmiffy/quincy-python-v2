# %% [markdown]
# ## 安装使用

# %% [markdown]
# - github地址：https://github.com/pyecharts/pyecharts
# - 示例地址： https://gallery.pyecharts.org/

# %% [markdown]
# 安装：`!pip install pyecharts -U`

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# V1 版本开始支持链式调用
bar = (
    Bar()
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"]) # x轴数据
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105]) # A商家：y轴数据
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49]) # B商家：y轴数据
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
)
bar.render_notebook()

# # 不习惯链式调用的开发者依旧可以单独调用方法
# bar = Bar()
# bar.add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
# bar.add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
# bar.add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
# bar.set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
# bar.render_notebook()
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bc1eaa8b3cb44bb0a0a57ab78c202b11" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bc1eaa8b3cb44bb0a0a57ab78c202b11 = echarts.init(
#                     document.getElementById('bc1eaa8b3cb44bb0a0a57ab78c202b11'), 'white', {renderer: 'canvas'});
#                 var option_bc1eaa8b3cb44bb0a0a57ab78c202b11 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...

# %% [markdown]
# ## 柱状图

# %% [markdown]
# ### Bar_base

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Bar-基本示例", subtitle="我是副标题"))
    
)
c.render_notebook()
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b2a90f8b403046038c9d506ca7c262bb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b2a90f8b403046038c9d506ca7c262bb = echarts.init(
#                     document.getElementById('b2a90f8b403046038c9d506ca7c262bb'), 'white', {renderer: 'canvas'});
#                 var option_b2a90f8b403046038c9d506ca7c262bb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...

# %% [markdown]
# ### Bar_datazoom_both

# %%
from pyecharts import options as op 
from pyecharts.charts import Bar
from pyecharts.faker import Faker

# %%
c=(
    Bar()
    .add_xaxis(Faker.days_attrs)
    .add_yaxis("商家A", Faker.days_values, color=Faker.rand_color())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-DataZoom（slider+inside）"),
        datazoom_opts=[opts.DataZoomOpts(), opts.DataZoomOpts(type_="inside")],
    )
)
c.render_notebook()
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="671a4fcffc0e42308dda0b76b2d80c6b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_671a4fcffc0e42308dda0b76b2d80c6b = echarts.init(
#                     document.getElementById('671a4fcffc0e42308dda0b76b2d80c6b'), 'white', {renderer: 'canvas'});
#                 var option_671a4fcffc0e42308dda0b76b2d80c6b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...
